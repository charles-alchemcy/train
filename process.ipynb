# %%
1 + 1
# Out:
# 2

# %%
import json
total = []
with open("datasets/train_data.jsonl" , "r") as f:
  for line in f.readlines():
    total.append(json.loads(line))
print(len(total))
# Out:
# 200000

# %%
print(min([min(total[i]['input_ids']) for i in range(200000)]))
# Out:
# 0
